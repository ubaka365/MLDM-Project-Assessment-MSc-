# %%
#importing libraries
import numpy as np
import pandas as pd
import sklearn as sk
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Here, I will be loading my dataset
dataset = pd.read_csv("students_data.csv")

# %%
dataset.shape
# Out:
# (4424, 37)

# %%
#showing all the elements in the dataset
dataset.iloc[:,:]
# Out:
#       Marital status  Application mode  Application order  Course  \
# 0                  1                17                  5     171
# 1                  1                15                  1    9254
# 2                  1                 1                  5    9070
# 3                  1                17                  2    9773
# 4                  2                39                  1    8014
# ...              ...               ...                ...     ...
# 4419               1                 1                  6    9773
# 4420               1                 1                  2    9773
# 4421               1                 1                  1    9500
# 4422               1                 1                  1    9147
# 4423               1                10                  1    9773
#
#       Daytime/evening attendance\t  Previous qualification  \
# 0                                1                       1
# ...

# %%
dataset.isnull().sum()
# Out:
# Marital status                                    0
# Application mode                                  0
# Application order                                 0
# Course                                            0
# Daytime/evening attendance\t                      0
# Previous qualification                            0
# Previous qualification (grade)                    0
# Nacionality                                       0
# Mother's qualification                            0
# Father's qualification                            0
# Mother's occupation                               0
# Father's occupation                               0
# Admission grade                                   0
# Displaced                                         0
# Educational special needs                         0
# Debtor                                            0
# Tuition fees up to date                           0
# Gender                                            0
# ...

# %%
#The code returns the header line and the first five rows of the dataset
dataset.head()
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                17                  5     171
# 1               1                15                  1    9254
# 2               1                 1                  5    9070
# 3               1                17                  2    9773
# 4               2                39                  1    8014
#
#    Daytime/evening attendance\t  Previous qualification  \
# 0                             1                       1
# 1                             1                       1
# 2                             1                       1
# 3                             1                       1
# 4                             0                       1
#
#    Previous qualification (grade)  Nacionality  Mother's qualification  \
# 0                           122.0            1                      19
# 1                           160.0            1                       1
# ...

# %%
#This returns the bottom five rows of the dataset
dataset.tail()
# Out:
#       Marital status  Application mode  Application order  Course  \
# 4419               1                 1                  6    9773
# 4420               1                 1                  2    9773
# 4421               1                 1                  1    9500
# 4422               1                 1                  1    9147
# 4423               1                10                  1    9773
#
#       Daytime/evening attendance\t  Previous qualification  \
# 4419                             1                       1
# 4420                             1                       1
# 4421                             1                       1
# 4422                             1                       1
# 4423                             1                       1
#
#       Previous qualification (grade)  Nacionality  Mother's qualification  \
# 4419                           125.0            1                       1
# ...

# %%
#we will be printing a concise summary of the dataset
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4424 entries, 0 to 4423
# Data columns (total 37 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Marital status                                  4424 non-null   int64
#  1   Application mode                                4424 non-null   int64
#  2   Application order                               4424 non-null   int64
#  3   Course                                          4424 non-null   int64
#  4   Daytime/evening attendance	                     4424 non-null   int64
#  5   Previous qualification                          4424 non-null   int64
#  6   Previous qualification (grade)                  4424 non-null   float64
#  7   Nacionality                                     4424 non-null   int64
#  8   Mother's qualification                          4424 non-null   int64
# ...

# %%
#This code returns a statistical description of the data in the dataframe
dataset.describe()
# Out:
#        Marital status  Application mode  Application order       Course  \
# count     4424.000000       4424.000000        4424.000000  4424.000000
# mean         1.178571         18.669078           1.727848  8856.642631
# std          0.605747         17.484682           1.313793  2063.566416
# min          1.000000          1.000000           0.000000    33.000000
# 25%          1.000000          1.000000           1.000000  9085.000000
# 50%          1.000000         17.000000           1.000000  9238.000000
# 75%          1.000000         39.000000           2.000000  9556.000000
# max          6.000000         57.000000           9.000000  9991.000000
#
#        Daytime/evening attendance\t  Previous qualification  \
# count                   4424.000000             4424.000000
# mean                       0.890823                4.577758
# std                        0.311897               10.216592
# min                        0.000000                1.000000
# ...

# %%
dataset.Target.value_counts()
# Out:
# Target
# Graduate    2209
# Dropout     1421
# Enrolled     794
# Name: count, dtype: int64

# %%
sns.countplot(dataset, x="Target")
# Out:
# <Axes: xlabel='Target', ylabel='count'>

# %%
#This codes includes all the information in the dataset
dataset.describe(include='all')
# Out:
#         Marital status  Application mode  Application order       Course  \
# count      4424.000000       4424.000000        4424.000000  4424.000000
# unique             NaN               NaN                NaN          NaN
# top                NaN               NaN                NaN          NaN
# freq               NaN               NaN                NaN          NaN
# mean          1.178571         18.669078           1.727848  8856.642631
# std           0.605747         17.484682           1.313793  2063.566416
# min           1.000000          1.000000           0.000000    33.000000
# 25%           1.000000          1.000000           1.000000  9085.000000
# 50%           1.000000         17.000000           1.000000  9238.000000
# 75%           1.000000         39.000000           2.000000  9556.000000
# max           6.000000         57.000000           9.000000  9991.000000
#
#         Daytime/evening attendance\t  Previous qualification  \
# ...

# %%
sns.histplot(dataset["GDP"])
plt.title("GDP")
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('')
sns.histplot(x="GDP", hue="Unemployment rate", data=dataset)
plt.show()

# %%
#import OneHotEncoder
from sklearn.preprocessing import OneHotEncoder

# %%
#Initialize the OneHotEncoder
enc = OneHotEncoder(drop='first')

# %%
#fitting the OneHotEncoder
students_gender=enc.fit_transform(dataset[["Gender"]]).toarray()

# %%
enc.categories_
# Out:
# [array([0, 1], dtype=int64)]

# %%
students_gender
# Out:
# array([[1.],
#        [1.],
#        [1.],
#        ...,
#        [0.],
#        [0.],
#        [0.]])

# %%
#creating a new dataframe into the datset
enc_data = pd.DataFrame(students_gender)

# %%
#merge the newly created dataframe to your initial dataset
students_gender = dataset.join(enc_data)

# %%
students_gender.head()
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                17                  5     171
# 1               1                15                  1    9254
# 2               1                 1                  5    9070
# 3               1                17                  2    9773
# 4               2                39                  1    8014
#
#    Daytime/evening attendance\t  Previous qualification  \
# 0                             1                       1
# 1                             1                       1
# 2                             1                       1
# 3                             1                       1
# 4                             0                       1
#
#    Previous qualification (grade)  Nacionality  Mother's qualification  \
# 0                           122.0            1                      19
# 1                           160.0            1                       1
# ...

# %%
students_gender.drop("Gender", axis=1)
# Out:
#       Marital status  Application mode  Application order  Course  \
# 0                  1                17                  5     171
# 1                  1                15                  1    9254
# 2                  1                 1                  5    9070
# 3                  1                17                  2    9773
# 4                  2                39                  1    8014
# ...              ...               ...                ...     ...
# 4419               1                 1                  6    9773
# 4420               1                 1                  2    9773
# 4421               1                 1                  1    9500
# 4422               1                 1                  1    9147
# 4423               1                10                  1    9773
#
#       Daytime/evening attendance\t  Previous qualification  \
# 0                                1                       1
# ...

# %%
#we use this code to determine class feature and input feature
x = students_gender.iloc[:,[1,2,3]].values
y = students_gender.iloc[:,4].values

# %%
#Then we split our dataset, into train and test dataset
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size = 0.3, random_state = 0)

# %%
#This code standardizes the train/test dataset
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train_s=sc.fit_transform(x_train)
x_test_s=sc.transform(x_test)

# %%
#After which we will be fitting K-NN to the training set, to train the model
from sklearn.neighbors import KNeighborsClassifier
classifier=KNeighborsClassifier(n_neighbors=5, metric ="minkowski", p=2)
classifier.fit(x_train_s, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       2 from sklearn.neighbors import KNeighborsClassifier
#       3 classifier=KNeighborsClassifier(n_neighbors=5, metric ="minkowski", p=2)
# ----> 4 classifier.fit(x_train_s, y_train)
#
# NameError: name 'x_train_s' is not defined

# %%
#Predicting the test set results using the trained model
y_pred=classifier.predict(x_test_s)
print(y_pred)
# Out:
# [1 1 1 ... 1 1 1]

# %%
print(y_test)
# Out:
# [1 1 1 ... 1 1 1]

# %%
#Now, we evaluate the performance of the model by typing the below code
from sklearn import metrics
acc=metrics.accuracy_score(y_test,y_pred)
print('accuracy:%2f\n\n'%(acc))
cm=metrics.confusion_matrix(y_test,y_pred)
print('Confusion Matrix:')
print(cm, '\n\n')
print('---------------------------------------------')
result=metrics.classification_report(y_test,y_pred)
print('Classification Report:\n')
print(result)
# Out:
# accuracy:0.996235
#
#
# Confusion Matrix:
# [[ 127    5]
#  [   0 1196]]
#
#
# ---------------------------------------------
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98       132
#            1       1.00      1.00      1.00      1196
#
#     accuracy                           1.00      1328
#    macro avg       1.00      0.98      0.99      1328
# weighted avg       1.00      1.00      1.00      1328

# %%
ax = sns.heatmap(cm, cmap='flare', annot=True, fmt='d')
plt.xlabel("Predicted Class", fontsize=12)
plt.ylabel("True Class",fontsize=12)
plt.title("Confusion Matrix",fontsize=12)

plt.show()
